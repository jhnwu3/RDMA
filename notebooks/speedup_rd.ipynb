# %%
import os
import sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)
# Set the parent directory as the current directory
os.chdir(parent_dir)

# %%
# load the dataset 
from utils.data import read_json_file, print_json_structure

dataset_path = "data/dataset/filtered_rd_annos_updated_adam.json"
dataset = read_json_file(dataset_path)
print_json_structure(dataset)
text = dataset["287"]["note_details"]["text"]
# print(text)
# Out:
# Dictionary:
#   287 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   869 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   1208 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   950 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   977 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   1552 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   1790 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   2452 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   2541 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   3390 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 5 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 6 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   4043 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   4806 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   4938 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   5873 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   10406 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   5738 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   6465 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   5811 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   7363 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   13231 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   7688 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   6188 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   8979 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 5 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   7699 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   6206 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   10004 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   10715 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   8877 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   9512 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   8001 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   8960 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   13600 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   16328 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   16334 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   16347 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   13666 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   14936 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   11052 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   11938 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   11604 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 5 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 6 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 7 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 8 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 9 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 10 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 11 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 12 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 13 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 14 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 15 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 16 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 17 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 18 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 19 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   22297 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   17850 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   15908 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   17640 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   20208 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 5 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 6 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 7 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 8 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 9 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 10 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 11 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 12 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 13 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   31392 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   24716 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   30442 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   31210 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   20162 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   25095 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
# ...
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   44246 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   41991 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   41739 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   54937 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   49532 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   49955 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   47713 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   49482 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   48386 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   48652 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   49514 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#   53382 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 5 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 6 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 7 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 8 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 9 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 10 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 11 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#       Item 12 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   53406 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 2 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 3 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 4 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   53691 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         start (int):
#         end (int):
#         type (str):
#         validated_false_positive (bool):
#   59366 (dict):
#   Dictionary:
#     note_details (dict):
#     Dictionary:
#       subject_id (str):
#       hadm_id (str):
#       category (str):
#       chartdate (str):
#       charttime (NoneType):
#       text (str):
#     annotations (list):
#     List:
#       Item 0 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):
#       Item 1 (dict):
#       Dictionary:
#         mention (str):
#         umls_with_desc (str):
#         ordo_with_desc (str):
#         gold_text_to_umls_label (int):
#         gold_text_to_ordo_label (int):
#         document_structure (str):
#         semehr_label (int):

# %%
def load_mistral_llm_client():
    """
    Load a Mistral 24B LLM client configured with default cache directories
    and assigned to cuda:0 device.
    
    Returns:
        LocalLLMClient: Initialized LLM client for Mistral 24B
    """
    from utils.llm_client import LocalLLMClient
    
    # Default cache directory from mine_hpo.py
    default_cache_dir = "/shared/rsaas/jw3/rare_disease/model_cache"
    
    # Initialize and return the client with specific configuration
    llm_client = LocalLLMClient(
        model_type="mistral_24b",  # Explicitly request mistral_24b model
        device="cuda:0",           # Assign to first GPU (cuda:0)
        cache_dir=default_cache_dir,
        temperature=0.1           # Default temperature from mine_hpo.py
    )
    
    return llm_client

llm_client = load_mistral_llm_client()
# Out:
# /home/johnwu3/miniconda3/envs/hporag/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Initialized ModelLoader with cache directory: /shared/rsaas/jw3/rare_disease/model_cache
# Loading LLM!
# Device configuration: cuda:0
# Using device map: {'': 'cuda:0'}
# Loading 70B model with quantization: mistral_24b
# Generated cache path: /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Valid cache found at /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Loading cached quantized model from /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# /home/johnwu3/miniconda3/envs/hporag/lib/python3.10/site-packages/transformers/quantizers/auto.py:206: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Hello! I'm here to help. How can I assist you today? If you have any medical questions or need information on a specific topic, feel free to ask. Please note that while I strive to provide accurate and helpful information, I am an AI and my knowledge cutoff is 2023, so I might not have real-time or up-to-date information. For urgent medical concerns, always consult a healthcare professional.
#
# Here are a few examples of how I can assist you:
#
# * Explain medical terms or concepts
# * Provide information on diseases, symptoms, and treatments
# * Offer insights into medical procedures and tests
# * Discuss healthcare guidelines and best practices
# * Answer questions related to biomedical research and studies
#
# What would you like to know or discuss?

# %%
from abc import ABC, abstractmethod
import json
import pandas as pd
import numpy as np
import re
from typing import List, Dict, Any, Optional, Tuple
from datetime import datetime
from fuzzywuzzy import fuzz
from hporag.context import ContextExtractor
from rdrag.entity import BaseRDExtractor

class RetrievalEnhancedRDExtractor(BaseRDExtractor):
    """
    Entity extractor that uses embedding retrieval to enhance LLM-based extraction.
    
    For each sentence:
    1. Retrieves relevant rare disease terms to provide context
    2. Uses this context to prompt the LLM for more accurate disease extraction
    
    This approach helps the LLM with domain knowledge before extraction begins.
    
    Features:
    - Optionally merges small sentences to ensure minimum chunk size for processing
    """
    
    def __init__(self, llm_client, embedding_manager, embedded_documents, 
                 system_message: str, top_k: int = 10, min_sentence_size: Optional[int] = None):
        """
        Initialize the retrieval-enhanced rare disease extractor.
        
        Args:
            llm_client: Client for querying the language model
            embedding_manager: Manager for vector embeddings and search
            embedded_documents: Rare disease terms with embeddings
            system_message: System message for LLM extraction
            top_k: Number of top candidates to retrieve per sentence
            min_sentence_size: Minimum character length for sentences (smaller ones will be merged)
        """
        self.llm_client = llm_client
        self.embedding_manager = embedding_manager
        self.embedded_documents = embedded_documents
        self.index = None
        self.system_message = system_message
        self.top_k = top_k
        self.min_sentence_size = min_sentence_size
        self.context_extractor = ContextExtractor()
        
    def prepare_index(self):
        """Prepare FAISS index from embedded documents if not already prepared."""
        if self.index is None:
            embeddings_array = self.embedding_manager.prepare_embeddings(self.embedded_documents)
            self.index = self.embedding_manager.create_index(embeddings_array)
    
    def _retrieve_candidates(self, sentence: str) -> List[Dict]:
        """
        Retrieve relevant rare disease candidates for a sentence.
        
        Args:
            sentence: Clinical sentence to find relevant rare disease terms for
            
        Returns:
            List of dictionaries with rare disease information and similarity scores
        """
        self.prepare_index()
        
        # Embed the query
        query_vector = self.embedding_manager.query_text(sentence).reshape(1, -1)
        
        # Search for similar items
        distances, indices = self.embedding_manager.search(query_vector, self.index, k=min(800, len(self.embedded_documents)))
        
        # Extract unique metadata
        candidates = []
        seen_metadata = set()
        
        for idx, distance in zip(indices[0], distances[0]):
            try:
                # Access document directly since it already has name, id, definition
                document = self.embedded_documents[idx]
                
                # Create an identifier for deduplication
                metadata_id = f"{document.get('name', '')}-{document.get('id', '')}"
                
                if metadata_id not in seen_metadata:
                    seen_metadata.add(metadata_id)
                    candidates.append({
                        'name': document.get('name', ''),
                        'id': document.get('id', ''),
                        'definition': document.get('definition', ''),
                        'similarity_score': 1.0 / (1.0 + distance)  # Convert distance to similarity
                    })
                    
                    if len(candidates) >= self.top_k:
                        break
            except Exception as e:
                print(f"Error processing metadata at index {idx}: {e}")
                continue
                    
        return candidates
    def _create_enhanced_prompt(self, sentence: str, candidates: List[Dict]) -> str:
        """
        Create a prompt enhanced with retrieved candidates.
        
        Args:
            sentence: Clinical sentence to extract rare diseases from
            candidates: Retrieved rare disease candidates to use as context
            
        Returns:
            Formatted prompt for LLM
        """
        # Format candidates as context
        context_items = []
        for candidate in candidates:
            context_items.append(f"- {candidate['name']} (ID: {candidate['id']})")
        
        context_text = "\n".join(context_items)
        
        # Create the enhanced prompt
        prompt = (
            f"I have CLINICAL TEXT: \"{sentence}\"\n\n"
            f"Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:\n\n"
            f"{context_text}\n\n"
            f"Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions "
            f"that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). "
            f"Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT."
            f"\n\nReturn only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. "
            f"Ensure the output is concise without any additional notes, commentary, or meta explanations."
        )
        
        return prompt
    
    def _merge_small_sentences(self, sentences: List[str], min_size: int) -> List[str]:
        """
        Merge sentences smaller than the minimum size with subsequent sentences.
        
        Args:
            sentences: List of extracted sentences
            min_size: Minimum character length for a sentence
            
        Returns:
            List of merged sentences meeting the minimum size requirement
        """
        if not sentences:
            return []
        
        if min_size is None or min_size <= 0:
            return sentences
            
        merged_sentences = []
        current_idx = 0
        
        while current_idx < len(sentences):
            current_sentence = sentences[current_idx]
            
            # If the current sentence is already large enough, add it directly
            if len(current_sentence) >= min_size:
                merged_sentences.append(current_sentence)
                current_idx += 1
                continue
            
            # Start merging with next sentences until we reach min_size
            merged_chunk = current_sentence
            next_idx = current_idx + 1
            
            while next_idx < len(sentences) and len(merged_chunk) < min_size:
                # Add the next sentence to our chunk with a space
                if merged_chunk and sentences[next_idx]:
                    merged_chunk += " " + sentences[next_idx]
                else:
                    merged_chunk += sentences[next_idx]
                next_idx += 1
            
            # Add the merged chunk to our results
            merged_sentences.append(merged_chunk)
            
            # Update the index to continue after the merged sentences
            current_idx = next_idx
        
        return merged_sentences
    
    def extract_entities(self, text: str) -> List[str]:
        """
        Extract rare disease mentions from text using retrieval-enhanced prompting.
        With sentence merging for efficiency when min_sentence_size is set.
        
        Args:
            text: Clinical text to extract rare disease mentions from
            
        Returns:
            List of extracted rare disease mentions
        """
        # Split text into sentences
        original_sentences = self.context_extractor.extract_sentences(text)
        
        # Merge small sentences if min_sentence_size is set
        if self.min_sentence_size:
            sentences = self._merge_small_sentences(original_sentences, self.min_sentence_size)
            print(f"After merging: Processing {len(sentences)} chunks instead of {len(original_sentences)} raw sentences")
        else:
            sentences = original_sentences
        
        all_entities = []
        
        for sentence in sentences:
            # Skip empty or very short sentences
            if not sentence or len(sentence) < 5:
                continue
                
            # Retrieve candidates for this sentence/chunk
            candidates = self._retrieve_candidates(sentence)
            
            # Create enhanced prompt
            prompt = self._create_enhanced_prompt(sentence, candidates)
            
            # Query LLM
            findings_text = self.llm_client.query(prompt, self.system_message)
            # Extract entities from response

            print("--------- DEBUG ---------")
            print(prompt)
            print()
            print(findings_text)
            print("------------------------")
            entities = self._extract_findings_from_response(findings_text)
            # Add to results
            all_entities.extend(entities)
        
        # Remove duplicates while preserving order
        unique_entities = []
        seen = set()
        for entity in all_entities:
            entity_lower = entity.lower()
            if entity_lower not in seen and entity:
                seen.add(entity_lower)
                unique_entities.append(entity)
        
        return unique_entities
    
    def _extract_findings_from_response(self, response: str) -> List[str]:
        """
        Parse LLM response to extract findings.
        
        Args:
            response: Raw LLM response text
            
        Returns:
            List of extracted entities
        """
        try:
            # Extract content between square brackets if present
            if '[' in response and ']' in response:
                response = response[response.find('[') + 1:response.rfind(']')]
            
            # Split on commas and clean up each term
            findings = []
            for term in response.split(','):
                cleaned_term = term.strip().strip('"\'')
                if cleaned_term:
                    findings.append(cleaned_term)
                    
            return findings
        except Exception as e:
            print(f"Error parsing LLM response: {str(e)}")
            return []
    
    def process_batch(self, texts: List[str]) -> List[List[str]]:
        """
        Process a batch of texts for rare disease extraction.
        
        Args:
            texts: List of clinical texts to process
            
        Returns:
            List of lists containing extracted rare disease mentions for each text
        """
        results = []
        for text in texts:
            entities = self.extract_entities(text)
            results.append(entities)
        return results
    
from utils.embedding import EmbeddingsManager
embedding_manager = EmbeddingsManager(
    model_type="sentence_transformer",
    model_name="abhinand/MedEmbed-small-v0.1",  # Medical-domain sentence transformer model
    device="cuda:0"
)

embedded_documents = np.load('/home/johnwu3/projects/rare_disease/workspace/repos/RDMA/data/vector_stores/rd_orpha_medembed.npy', allow_pickle=True)
extractor = RetrievalEnhancedRDExtractor(llm_client, 
                                         embedding_manager, 
                                         embedded_documents, 
                                         system_message="You are a rare disease expert. Please extract disease mentions from the text.", 
                                         min_sentence_size=500,
                                         top_k=10)
extracted = extractor.extract_entities(text)
# Out:
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cuda:0
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cuda:0
# Model successfully moved to cuda:0
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# After merging: Processing 24 chunks instead of 337 raw sentences
# --------- DEBUG ---------
# I have CLINICAL TEXT: "Admission Date:  [**2130-11-13**]       Discharge Date:  [**2130-12-6**] Service:  MICU HISTORY OF PRESENT ILLNESS:   The patient is an 85-year-old woman with a history of congestive heart failure, peripheral vascular disease, Type 2 diabetes mellitus, and Parkinson's disease, who was admitted after being found unresponsive at home. The patient was in her usual state of health until 1 P. M. on the day of admission, when she was found by her cousin, who lives with her. The patient was unresponsive,"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - msa (ID: Orpha:102)
# - caps (ID: Orpha:464343)
# - cerebral sinovenous thrombosis (ID: ORPHA:329217)
# - kikuchi-fujimoto disease (ID: ORPHA:50918)
# - kikuchi-fujimoto disease (ID: Orpha:50918)
# - stress cardiomyopathy (ID: Orpha:66529)
# - familial sick sinus syndrome (ID: ORPHA:166282)
# - hemiconvulsion-hemiplegia-epilepsy syndrome (ID: ORPHA:86908)
# - maternally-inherited cardiomyopathy and deafness (ID: Orpha:1349)
# - tako-tsubo cardiomyopathy (ID: Orpha:66529)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "congestive heart failure",
#     "peripheral vascular disease",
#     "Type 2 diabetes mellitus",
#     "Parkinson's disease"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "apparently no longer than 30 seconds. She slumped forward, and EMS was called. There were no preceding palpitations, shortness of breath, chest pain, focal weakness, dysarthria, bowel or bladder incontinence, or seizure activity noted. EMS noted the patient to have a finger stick blood glucose of 240, atrial fibrillation on the monitor, with a rate of 100, blood pressure of 136/palp, respiration rate of 4, and initially unresponsive. Her pupils were equal, round and reactive to light. The patient was intubated and, during intubation, she was"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - cyanide poisoning (ID: ORPHA:466670)
# - systemic monochloroacetate poisoning (ID: ORPHA:90069)
# - acute poisoning by drugs with membrane-stabilizing effect (ID: ORPHA:43119)
# - paracetamol poisoning (ID: ORPHA:464458)
# - exertional heat stroke (ID: Orpha:466650)
# - delayed encephalopathy due to co poisoning (ID: Orpha:306686)
# - amniotic fluid embolism (ID: ORPHA:617304)
# - delayed encephalopathy due to carbon monoxide poisoning (ID: ORPHA:306686)
# - delayed encephalopathy due to carbon monoxide poisoning (ID: Orpha:306686)
# - acute tricyclic antidepressant poisoning (ID: ORPHA:43117)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "atrial fibrillation"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "noted to have increased agitation. She was given 2 mg of Versed, successfully intubated, and sent to [**Hospital1 346**], where she was immediately brought to the Medical Intensive Care Unit. Upon arrival, she was hemodynamically stable. PAST MEDICAL HISTORY: 1. Congestive heart failure, last echocardiogram in [**2130-8-14**] showed mild symmetric left ventricular hypertrophy, an ejection fraction of greater than 55%, and 1+ aortic insufficiency and mitral regurgitation. There was normal right ventricular function."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - postcardiotomy right ventricular failure (ID: ORPHA:263352)
# - stress cardiomyopathy (ID: Orpha:66529)
# - ampulla cardiomyopathy (ID: Orpha:66529)
# - transient left ventricular apical ballooning syndrome (ID: Orpha:66529)
# - ballooning cardiomyopathy (ID: Orpha:66529)
# - familial isolated dilated cardiomyopathy (ID: ORPHA:154)
# - familial isolated dilated cardiomyopathy (ID: Orpha:154)
# - dilated cardiomyopathy (ID: ORPHA:217604)
# - takotsubo cardiomyopathy (ID: Orpha:66529)
# - tako-tsubo cardiomyopathy (ID: Orpha:66529)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "Congestive heart failure",
#     "left ventricular hypertrophy",
#     "aortic insufficiency",
#     "mitral regurgitation"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "She was admitted in [**2130-8-14**] with increasing peripheral edema and orthopnea. She was diuresed 3 liters, ruled out by enzymes, and had a negative ETT MIBI. 2. Hypercholesterolemia 3. Hypertension 4. Peripheral vascular disease status post bilateral carotid endarterectomy in [**2121**] 5. Type 2 diabetes mellitus with peripheral neuropathy and glaucoma 6. Parkinson's disease, followed by neurologist Dr. [**Last Name (STitle) **] 7. Osteoarthritis ALLERGIES:   There are no known drug allergies."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - retinal vasculopathy with cerebral leukoencephalopathy and systemic manifestations (ID: ORPHA:247691)
# - retinal vasculopathy with cerebral leukoencephalopathy and systemic manifestations (ID: Orpha:247691)
# - autoimmune encephalopathy with parasomnia and obstructive sleep apnea (ID: ORPHA:420789)
# - cathepsin a-related arteriopathy-strokes-leukoencephalopathy (ID: ORPHA:575553)
# - multiple paragangliomas associated with polycythemia (ID: ORPHA:324299)
# - retinal vasculopathy and cerebral leukoencephalopathy (ID: Orpha:247691)
# - baroreflex failure (ID: ORPHA:443084)
# - internal carotid absence (ID: ORPHA:981)
# - acute peripheral arterial occlusion (ID: ORPHA:90064)
# - acute peripheral arterial occlusion (ID: Orpha:90064)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "peripheral edema",
#     "orthopnea",
#     "Hypercholesterolemia",
#     "Hypertension",
#     "Peripheral vascular disease",
#     "Type 2 diabetes mellitus",
#     "peripheral neuropathy",
#     "glaucoma",
#     "Parkinson's disease",
#     "Osteoarthritis"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "MEDICATIONS:   Sinemet 25/100 one-half tablet by mouth three times a day, Lidoderm patch, Timoptic and Xalatan eyedrops one drop per eye every day, Miacalcin spray one spray alternating nostrils once daily, NPH insulin 5 units subcutaneously every morning, Neurontin 600 mg by mouth three times a day, atenolol 75 mg by mouth once daily, lasix 40 mg by mouth every Monday, Wednesday and Friday, Protonix 40 mg by mouth once daily, Zestril 5 mg by mouth once daily. SOCIAL HISTORY:   She lives with her cousin."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - insulin (ID: ORPHA:168345)
# - congenital hypothyroidism due to maternal intake of antithyroid drugs (ID: Orpha:226313)
# - pustular drug eruption (ID: Orpha:293173)
# - drug rash with eosinophilia and systemic symptoms (ID: Orpha:139402)
# - drug reaction with eosinophilia and systemic symptoms (ID: ORPHA:139402)
# - drug reaction with eosinophilia and systemic symptoms (ID: Orpha:139402)
# - familial hibernian fever (ID: Orpha:32960)
# - fixed drug eruption (ID: ORPHA:293812)
# - fixed drug eruption (ID: Orpha:293812)
# - hyperinsulinemic hypoglycemia due to insulin receptor deficiency (ID: Orpha:263458)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# ["NPH insulin"]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "She is minimally ambulatory at baseline. She uses a wheelchair and a walker, needs help with her activities of daily living. She quit tobacco 15 years ago. The patient had been at [**Hospital3 2732**] Home for approximately one and a half months following her [**Month (only) 359**] admission for congestive heart failure. While there, she had been placed on supplemental oxygen by nasal cannula. She was discharged home on oxygen one and a half weeks prior to her readmission. FAMILY HISTORY:   Father died of a myocardial infarction at"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - familial restrictive cardiomyopathy (ID: ORPHA:217635)
# - familial dilated cardiomyopathy (ID: Orpha:217607)
# - familial dilated cardiomyopathy (ID: ORPHA:217607)
# - familial isolated dilated cardiomyopathy (ID: ORPHA:154)
# - familial isolated dilated cardiomyopathy (ID: Orpha:154)
# - cact deficiency (ID: Orpha:159)
# - carnitine-acylcarnitine translocase deficiency (ID: ORPHA:159)
# - carnitine-acylcarnitine translocase deficiency (ID: Orpha:159)
# - familial progressive heart block (ID: Orpha:871)
# - non-familial restrictive cardiomyopathy (ID: ORPHA:217720)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "congestive heart failure"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "age 39. REVIEW OF SYSTEMS:   Stable four-pillow orthopnea, decreasing peripheral edema over baseline, stable dyspnea on exertion, no chest pain, oxygen 2 liters nasal cannula at home, no fevers or chills, no abdominal pain, no change in urinary symptoms, no cough. PHYSICAL EXAMINATION:   Temperature 98. 4, heart rate 82 and regular, blood pressure 154/57, respirations 15, oxygen saturation 96%, weight 90. 9 kg. Ventilated on IMV mode with tidal volumes of 700, rate of 10, pressure support of 5, and"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - hape (ID: Orpha:330012)
# - high altitude pulmonary edema (ID: ORPHA:330012)
# - high altitude pulmonary edema (ID: Orpha:330012)
# - bpd (ID: Orpha:70589)
# - infant ards (ID: Orpha:70587)
# - infant respiratory distress syndrome (ID: Orpha:70587)
# - young syndrome (ID: Orpha:3471)
# - infantile apnea (ID: ORPHA:70590)
# - adult ards (ID: Orpha:70578)
# - infant acute respiratory distress syndrome (ID: Orpha:70587)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["orthopnea", "dyspnea", "IMV", "ards"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "PEEP of 5, with FIO2 of 100%. In general, intubated, responding to questions, appears comfortable. Head, eyes, ears, nose and throat:  Normocephalic, atraumatic, extraocular movements intact, pupils equal, round and reactive to light, mucous membranes moist, no lesions. Neck: Jugular venous pressure difficult to determine. There is a left carotid bruit. Cardiovascular:  Regular rate and rhythm, normal S1 and S2, I/VI systolic murmur at the upper sternal border. Lungs:  Decreased breath sounds at the right"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - hape (ID: Orpha:330012)
# - persistent eustachian valve (ID: ORPHA:99120)
# - ecaa (ID: Orpha:494424)
# - uapa (ID: Orpha:980)
# - ecca (ID: Orpha:494424)
# - extracranial carotid artery aneurysm (ID: ORPHA:494424)
# - extracranial carotid artery aneurysm (ID: Orpha:494424)
# - mdds (ID: Orpha:210272)
# - unilateral pulmonary artery absence (ID: Orpha:980)
# - non rare in europe: normal pressure hydrocephalus (ID: ORPHA:314928)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "PEEP",
#     "FIO2",
#     "intubated",
#     "Normocephalic",
#     "atraumatic",
#     "extraocular movements",
#     "pupils",
#     "mucous membranes",
#     "lesions",
#     "Jugular venous pressure",
#     "left carotid bruit",
#     "Cardiovascular",
#     "rate and rhythm",
#     "S1 and S2",
#     "I/VI systolic murmur",
#     "Lungs",
#     "Decreased breath sounds"
# ]
# ```
# ------------------------
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# --------- DEBUG ---------
# I have CLINICAL TEXT: "base, otherwise clear to auscultation bilaterally, without rales, rhonchi or wheezes. Abdomen:  Soft, obese, nondistended, right lower quadrant and left lower quadrant mildly tender, no rebound, no guarding, positive bowel sounds. Extremities:  Trace pretibial edema bilaterally, no cords. Rectal:  Guaiac negative, normal tone. Neurological: Cranial nerves II through XII intact, moving all extremities, equal strength, [**3-18**] throughout upper and lower. Sensation normal throughout. Patellar reflexes 2+ bilaterally, absent"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - rectal duplication (ID: ORPHA:171220)
# - primary desmosis coli (ID: ORPHA:565641)
# - familial rectal pain (ID: Orpha:46348)
# - retained medullary cord (ID: ORPHA:645334)
# - sensorineural deafness with imperforate anus and hypoplastic thumbs (ID: Orpha:857)
# - hearing loss-small bowel diverticulosis-neuropathy syndrome (ID: Orpha:3217)
# - anal fistula (ID: ORPHA:228113)
# - deafness-small bowel diverticulosis-neuropathy syndrome (ID: ORPHA:3217)
# - deafness-small bowel diverticulosis-neuropathy syndrome (ID: Orpha:3217)
# - chronic intestinal pseudoobstruction (ID: ORPHA:2978)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "edema",
#     "Guaiac negative"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "ankle jerks. Left upper extremity with resting tremor. LABORATORY DATA:   On admission, white blood cells 4. 1, hematocrit 29. 2, platelets 227. PT 13. 3, PTT 29. 9, and INR 1. 2. Sodium 138, potassium 4. 8, chloride 94, bicarbonate 33, BUN 30, creatinine 1. 2, glucose 121. Magnesium 2. 1, phosphate 3. 7, calcium not measured. ALT 9, AST 71, alkaline phosphatase 80, total bilirubin 0. 5, albumin 3. 2, serum osmolality 298. CPK and troponin were negative. Urinalysis was negative for urinary tract infection."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - autosomal dominant myoglobinuria (ID: ORPHA:99846)
# - arhr (ID: Orpha:289176)
# - hereditary hypophosphatemic rickets with hypercalciuria (ID: ORPHA:157215)
# - hereditary hypophosphatemic rickets with hypercalciuria (ID: Orpha:157215)
# - calpain-3-related limb-girdle muscular dystrophy d4 (ID: ORPHA:565909)
# - isolated asymptomatic hyperckemia (ID: Orpha:206599)
# - isolated asymptomatic elevation of creatine phosphokinase (ID: ORPHA:206599)
# - isolated asymptomatic elevation of creatine phosphokinase (ID: Orpha:206599)
# - autosomal recessive hypophosphatemic rickets (ID: ORPHA:289176)
# - autosomal recessive hypophosphatemic rickets (ID: Orpha:289176)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "ankle jerks",
#     "resting tremor",
#     "PT",
#     "PTT",
#     "INR",
#     "BUN",
#     "CPK",
#     "troponin"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "Serum toxicology screen was negative. Urine toxicology screen was positive for benzodiazepines. Arterial blood gas was 7. 55/36/220 on 100% FIO2 with the ventilator settings as listed above. CT scan of the head showed no intracerebral bleed. Chest x-ray showed bilateral hilar fullness and upper zone redistribution. Electrocardiogram was normal sinus rhythm at 78, with normal axis. There were peaked T waves in Leads V2 through V6. There were no ST or T changes suggestive of ischemia, no Q waves consistent with electrocardiogram"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - cyanide poisoning (ID: ORPHA:466670)
# - acute tricyclic antidepressant poisoning (ID: ORPHA:43117)
# - acute poisoning by drugs with membrane-stabilizing effect (ID: ORPHA:43119)
# - cocaine intoxication (ID: ORPHA:90068)
# - cocaine intoxication (ID: Orpha:90068)
# - systemic monochloroacetate poisoning (ID: ORPHA:90069)
# - delayed encephalopathy due to carbon monoxide poisoning (ID: ORPHA:306686)
# - delayed encephalopathy due to carbon monoxide poisoning (ID: Orpha:306686)
# - drug- or toxin-induced pulmonary arterial hypertension (ID: ORPHA:275786)
# - drug-induced methemoglobinemia (ID: Orpha:464453)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["bilateral hilar fullness", "upper zone redistribution", "normal sinus rhythm", "peaked T waves"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "performed in [**2130-8-14**]. IMPRESSION:   This was an 85-year-old woman with a history of diastolic dysfunction, Type 2 diabetes mellitus, Parkinson's disease, who was found unresponsive and intubated in the field, but whose neurologic function upon admission appeared to be at baseline. HOSPITAL COURSE:   Initially the patient's primary disorder was thought to be neurologic in origin. Therefore, the Neurology service was consulted. It was thought that perhaps the patient had a basilar artery transient ischemic attack."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - acquired aneurysmal subarachnoid hemorrhage (ID: ORPHA:90065)
# - acquired aneurysmal subarachnoid hemorrhage (ID: Orpha:90065)
# - pediatric arterial ischemic stroke (ID: ORPHA:439175)
# - short-lasting unilateral neuralgiform headache attacks with conjunctival injection and tearing (ID: Orpha:57145)
# - idiopathic recurrent stupor (ID: ORPHA:276174)
# - paf (ID: Orpha:441)
# - pure autonomic failure (ID: ORPHA:441)
# - pure autonomic failure (ID: Orpha:441)
# - idiopathic moyamoya disease (ID: Orpha:2573)
# - pure dysautonomia (ID: Orpha:441)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "diastolic dysfunction",
#     "Type 2 diabetes mellitus",
#     "Parkinson's disease",
#     "basilar artery transient ischemic attack"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "A head CT was performed, and this was negative. Therefore, it was thought that the patient did not have a primary neurologic event. She ruled out for myocardial infarction. There was no recurrence of the atrial fibrillation noted on the monitor in the field. Her aspirin, atenolol, Zestril and Lipitor were continued. Two days after admission, on the [**8-15**], while the patient's cousin was visiting, the patient was noted to slump over and become unresponsive for a second time. Rhythm strip showed junctional escape with a heart rate of 15."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - familial progressive heart block (ID: Orpha:871)
# - familial lev-lenègre disease (ID: Orpha:871)
# - familial progressive cardiac conduction defect (ID: ORPHA:871)
# - familial progressive cardiac conduction defect (ID: Orpha:871)
# - familial lev disease (ID: Orpha:871)
# - rare atrial defect and interatrial communication (ID: ORPHA:98727)
# - familial lenègre disease (ID: Orpha:871)
# - familial sick sinus syndrome (ID: ORPHA:166282)
# - familial atrial fibrillation (ID: ORPHA:334)
# - familial atrial fibrillation (ID: Orpha:334)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "myocardial infarction",
#     "atrial fibrillation"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "She was assumed to be in bradycardic arrest. She was intubated for a second time, and the electrophysiology division of the Cardiology service was consulted. She was thought to have a sick sinus syndrome, and a DDD pacer was placed. Lasix was given for diuresis. She received bronchoscopy, which removed a large dried mucous plug at the tip of the endotracheal tube. Bronchial washings from that bronchoscopy revealed only gram-negative rods on Gram [**Last Name (LF) 2733**], [**First Name3 (LF) **] she was started on"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - rare intoxication due to medical products (ID: ORPHA:306640)
# - acute poisoning by drugs with membrane-stabilizing effect (ID: ORPHA:43119)
# - familial sick sinus syndrome (ID: ORPHA:166282)
# - non-syndromic bridging bronchus (ID: ORPHA:648992)
# - vidd (ID: Orpha:505395)
# - hape (ID: Orpha:330012)
# - persistent left superior vena cava connecting to the roof of left-sided atrium (ID: ORPHA:99111)
# - familial spontaneous pneumothorax (ID: ORPHA:2903)
# - familial spontaneous pneumothorax (ID: Orpha:2903)
# - pneumocystosis (ID: ORPHA:723)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["bradycardic arrest", "sick sinus syndrome", "DDD pacer", "gram-negative rods"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "ceftriaxone and Flagyl. The following day, on the [**8-17**], she was extubated. However, she required very high levels of oxygen to maintain her saturations above 90%. To investigate this, a chest x-ray was performed which revealed bilateral pleural effusions, as well as cardiomegaly. An echocardiogram was performed that showed mild symmetric left ventricular hypertrophy, preserved left ventricular function with an ejection fraction greater than 55%, normal right ventricular systolic function, trace aortic regurgitation, mild mitral"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - loeffler endocarditis (ID: ORPHA:75566)
# - loeffler endocarditis (ID: Orpha:75566)
# - temf (ID: Orpha:75565)
# - drug- or toxin-induced pulmonary arterial hypertension (ID: ORPHA:275786)
# - eosinophilic endocarditis (ID: Orpha:75566)
# - tropical endomyocardial fibrosis (ID: Orpha:75565)
# - tropical endomyocardial fibrosis (ID: ORPHA:75565)
# - fixed subaortic stenosis (ID: ORPHA:3092)
# - fixed subaortic stenosis (ID: Orpha:3092)
# - familial isolated dilated cardiomyopathy (ID: ORPHA:154)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#   "pleural effusions",
#   "cardiomegaly",
#   "left ventricular hypertrophy",
#   "aortic regurgitation",
#   "mitral"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "regurgitation, and no pericardial effusion. There was no change compared to the echocardiogram performed in [**2130-8-14**]. In light of these findings, we postulated that the cause of her poor oxygenation was multifactorial, including restrictive lung disease from obesity and cardiomegaly, as well as her pleural effusions. She was continued on lasix for diuresis and, on [**11-19**], was transferred to the general medical floor for further management. On [**11-20**], while in the Radiology Department following an"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - postcardiotomy right ventricular failure (ID: ORPHA:263352)
# - vidd (ID: Orpha:505395)
# - ventricular septal defect with aortic insufficiency (ID: Orpha:99094)
# - familial isolated dilated cardiomyopathy (ID: ORPHA:154)
# - familial isolated dilated cardiomyopathy (ID: Orpha:154)
# - vsd with aortic insufficiency (ID: Orpha:99094)
# - pulmonary valve agenesis-intact ventricular septum-persistent ductus arteriosus syndrome (ID: ORPHA:99048)
# - hape (ID: Orpha:330012)
# - congenital stenosis of pulmonary valve (ID: Orpha:3189)
# - familial or idiopathic dilated cardiomyopathy (ID: Orpha:154)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "restrictive lung disease",
#     "cardiomegaly",
#     "pleural effusions"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "x-ray, she was found on the stretcher with an ashen appearance, diaphoretic, and unresponsive. A code was called. Her portable oxygen tank was noted to be empty. When her mask was hooked up to wall oxygen, she gradually gained consciousness and there were no residual deficits. On [**11-22**], she underwent thoracentesis on the right, which was the larger of her effusions. 300 cc of serosanguinous exudative fluid were drained. The cytology was negative. The following day, she underwent diagnostic bronchoscopy,"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - hape (ID: Orpha:330012)
# - meconium aspiration syndrome (ID: ORPHA:70588)
# - meconium aspiration syndrome (ID: Orpha:70588)
# - high altitude pulmonary edema (ID: ORPHA:330012)
# - high altitude pulmonary edema (ID: Orpha:330012)
# - asbestosis (ID: Orpha:2302)
# - asbestos intoxication (ID: ORPHA:2302)
# - asbestos intoxication (ID: Orpha:2302)
# - non-syndromic bridging bronchus (ID: ORPHA:648992)
# - neonatal acute respiratory distress due to sp-b deficiency (ID: Orpha:217563)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["asthen appearance", "effusions"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "which was essentially unremarkable. Later that night, she had increasing hypoxia, a temperature of 100. 8, a white count of 14, and a chest x-ray which showed increasing bilateral effusions. She had warm extremities. Therefore, it was felt that she was likely in septic shock with bacterial source being from a primary pulmonary infection. She was transferred to the Medical Intensive Care Unit, where central access was obtained and she was started on dopamine for pressure support. She received noninvasive positive pressure"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - hape (ID: Orpha:330012)
# - high altitude pulmonary edema (ID: ORPHA:330012)
# - high altitude pulmonary edema (ID: Orpha:330012)
# - exertional heat stroke (ID: Orpha:466650)
# - cardiogenic shock (ID: ORPHA:97292)
# - cardiogenic shock (ID: Orpha:97292)
# - chronic thromboembolic pulmonary hypertension (ID: ORPHA:70591)
# - chronic thromboembolic pulmonary hypertension (ID: Orpha:70591)
# - drug- or toxin-induced pulmonary arterial hypertension (ID: ORPHA:275786)
# - exercise-induced malignant hyperthermia (ID: ORPHA:466650)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["septic shock"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "ventilation and nebulized treatments. A CT scan of the chest on [**11-24**] showed moderate bilateral effusions and multifocal opacities, consistent with pneumonia. Incidental note was made of a left adrenal mass, most consistent with an adenoma. Since she developed this pneumonia while she was in the hospital, we covered her broadly with vancomycin, ceftazidime and Flagyl. We continued with NIPPV for two more days, but she did not significantly improve. Therefore, on [**11-27**], she was reintubated."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - pneumocystosis (ID: ORPHA:723)
# - pneumocystosis (ID: Orpha:723)
# - pneumonia caused by pseudomonas aeruginosa infection (ID: ORPHA:90066)
# - pulmonary non-tuberculous mycobacterial infection (ID: ORPHA:411703)
# - pulmonary non-tuberculous mycobacterial infection (ID: Orpha:411703)
# - primary mediastinal large b-cell lymphoma (ID: ORPHA:98838)
# - azoospermia-sinopulmonary infections syndrome (ID: Orpha:3471)
# - pleural empyema (ID: ORPHA:449266)
# - staphylococcal necrotizing pneumonia (ID: ORPHA:36238)
# - staphylococcal necrotizing pneumonia (ID: Orpha:36238)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "pneumonia"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "Fentanyl was used for sedation, and dopamine was continued. The following day, she received diagnostic bronchoscopy for a specimen collection, but these grew only oropharyngeal flora. Thus in the absence of a predominant pathogen, her antibiotic therapy was eventually changed to levofloxacin and Flagyl on [**11-30**]. On that same day, she was changed from assist control mode to SIMV plus pressure support. She tolerated this well. She had a very brief temperature spike to 101. 4 on [**12-1**], but no increase in white count was noted, and"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - hyperthermia of anesthesia (ID: Orpha:423)
# - indomethacin embryofetopathy (ID: ORPHA:1909)
# - indomethacin embryofetopathy (ID: Orpha:1909)
# - malignant hyperthermia of anesthesia (ID: ORPHA:423)
# - malignant hyperthermia of anesthesia (ID: Orpha:423)
# - sideroflexin 4 (ID: ORPHA:392296)
# - drug- or toxin-induced pulmonary arterial hypertension (ID: ORPHA:275786)
# - fetal indomethacin syndrome (ID: Orpha:1909)
# - flavin containing dimethylaniline monoxygenase 3 (ID: ORPHA:121876)
# - prodynorphin (ID: ORPHA:212594)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# [
#     "malignant hyperthermia"
# ]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "she had no subsequent temperature spikes. In light of the patient's very slow recovery from her pneumonia, multiple discussions were held with the patient as well as with her family to discuss the patient's end of life issues. The patient made it very clear that she wished to proceed with maximal medical management providing that she still had a chance to recover from her pneumonia. Therefore, on [**12-5**], she received tracheotomy and percutaneous endoscopic gastrostomy for anticipated discharge to inpatient"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - exertional heat stroke (ID: Orpha:466650)
# - ventilator-induced diaphragmatic dysfunction (ID: ORPHA:505395)
# - ventilator-induced diaphragmatic dysfunction (ID: Orpha:505395)
# - exercise-induced malignant hyperthermia (ID: ORPHA:466650)
# - exercise-induced malignant hyperthermia (ID: Orpha:466650)
# - diazoxide-resistant focal hyperinsulinism due to sur1 deficiency (ID: ORPHA:276598)
# - primary hemophagocytic lymphohistiocytosis without hypopigmentation (ID: ORPHA:664482)
# - sickness of disembarkment (ID: Orpha:210272)
# - acute encephalopathy with biphasic seizures and late reduced diffusion (ID: ORPHA:363549)
# - acute encephalopathy with biphasic seizures and late reduced diffusion (ID: Orpha:363549)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# ["pneumonia"]
# ```
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "rehabilitation. Additional aspects of her hospital stay were as follows: Cardiovascular:  We discontinued the patient's beta blockade and ACE inhibitor in light of her hypotension. We continued her Lipitor and aspirin. Gastrointestinal:  She was placed on Prevacid for gastrointestinal prophylaxis. Nutrition:  She was fed by tube feeds via an orogastric tube, which was later changed to a percutaneous endoscopic gastrostomy. Endocrine:  We maintained adequate blood glucose control via NPH insulin and a regular insulin sliding scale."
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - persistent hyperinsulinemic hypoglycemia of infancy (ID: Orpha:657)
# - diazoxide-resistant focal hyperinsulinism due to sur1 deficiency (ID: ORPHA:276598)
# - hyperinsulinemic hypoglycemia due to short chain 3-hydroxylacyl-coa dehydrogenase deficiency (ID: Orpha:71212)
# - hyperinsulinism due to schad deficiency (ID: Orpha:71212)
# - hyperinsulinemic hypoglycemia due to hnf4a deficiency (ID: Orpha:263455)
# - hyperinsulinemic hypoglycemia due to ucp2 deficiency (ID: Orpha:276556)
# - hyperinsulinism due to short chain 3-hydroxylacyl-coa dehydrogenase deficiency (ID: ORPHA:71212)
# - hyperinsulinism due to short chain 3-hydroxylacyl-coa dehydrogenase deficiency (ID: Orpha:71212)
# - hyperinsulinism due to glutamodehydrogenase deficiency (ID: Orpha:71212)
# - schad deficiency (ID: Orpha:71212)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["hypotension", "NPH insulin", "insulin"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "Neurology:  We continued the patient on Neurontin and Sinemet. Hematology:  The patient has a baseline anemia, which responded well to periodic transfusion. Her baseline hematocrit is approximately 30. 0. Prophylaxis:  The patient was on heparin for deep venous thrombosis prophylaxis, and Prevacid for gastrointestinal prophylaxis. Code status:  With multiple discussions held with the patient and her family, it was determined that she was Full Code. DISPOSITION:   The patient will be discharged to inpatient"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - beta-thalassemia-x-linked thrombocytopenia syndrome (ID: ORPHA:231393)
# - beta-thalassemia-x-linked thrombocytopenia syndrome (ID: Orpha:231393)
# - aregenerative anemia (ID: Orpha:101096)
# - xltt (ID: Orpha:231393)
# - pale (ID: Orpha:163921)
# - chuvash erythrocytosis (ID: ORPHA:238557)
# - posttransplant acute limbic encephalitis (ID: ORPHA:163921)
# - posttransplant acute limbic encephalitis (ID: Orpha:163921)
# - hemiconvulsion-hemiplegia-epilepsy syndrome (ID: ORPHA:86908)
# - x-linked congenital dyserythropoietic anemia with thrombocytopenia (ID: Orpha:67044)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ["anemia", "deep venous thrombosis", "Full Code"]
# ------------------------
# --------- DEBUG ---------
# I have CLINICAL TEXT: "rehabilitation once accepted at a rehabilitation facility. Discharge instructions and medication list will be provided on the discharge addendum. [**First Name4 (NamePattern1) **] [**Last Name (NamePattern1) **] [**Name8 (MD) **], M. D. [**MD Number(1) 292**] Dictated By:[**Name8 (MD) 2734**] MEDQUIST36 D:  [**2130-12-6**]  00:33 T:  [**2130-12-6**]  00:56 JOB#:  [**Job Number 2735**]"
#
# Here are some relevant rare disease terms for reference that may help you find rare disease mentions in the sentence:
#
# - autosomal recessive spastic paraplegia type 68 (ID: Orpha:401825)
# - obsolete: intellectual disability-cataracts-kyphosis syndrome (ID: Orpha:171860)
# - obsolete: early-onset schizophrenia (ID: Orpha:96369)
# - obsolete: x-linked intellectual disability-obesity-short stature syndrome (ID: Orpha:85331)
# - obsolete: x-linked dominant intellectual disability-epilepsy syndrome (ID: Orpha:93951)
# - spastic paraplegia-epilepsy-intellectual disability syndrome (ID: Orpha:2816)
# - plan (ID: Orpha:35069)
# - obsolete: spondylocostal dysostosis-hypospadias-intellectual disability syndrome (ID: Orpha:329252)
# - dystonia 15, myoclonic (ID: ORPHA:306169)
# - inclusion body myopathy with paget disease of bone and frontotemporal dementia (ID: ORPHA:52430)
#
# Based on this sentence and the provided rare disease terms as reference, extract all potential disease mentions that are NOT negated (i.e., NOT preceded by 'no', 'not', 'without', 'ruled out', etc.). Please also include any potential abbreviations that might be referring to rare diseases in the CLINICAL TEXT.
#
# Return only a Python list of strings, with each disease exactly as it appears in the CLINICAL TEXT. Ensure the output is concise without any additional notes, commentary, or meta explanations.
#
# ```python
# []
# ```
# ------------------------

# %%
print(extracted)
# Out:
# ['congestive heart failure', 'peripheral vascular disease', 'Type 2 diabetes mellitus', "Parkinson's disease", 'atrial fibrillation', 'left ventricular hypertrophy', 'aortic insufficiency', 'mitral regurgitation', 'peripheral edema', 'orthopnea', 'Hypercholesterolemia', 'Hypertension', 'peripheral neuropathy', 'glaucoma', 'Osteoarthritis', 'NPH insulin', 'dyspnea', 'IMV', 'ards', 'PEEP', 'FIO2', 'intubated', 'Normocephalic', 'atraumatic', 'extraocular movements', 'pupils', 'mucous membranes', 'lesions', 'Jugular venous pressure', 'left carotid bruit', 'Cardiovascular', 'rate and rhythm', 'S1 and S2', 'I/VI systolic murmur', 'Lungs', 'Decreased breath sounds', 'edema', 'Guaiac negative', 'ankle jerks', 'resting tremor', 'PT', 'PTT', 'INR', 'BUN', 'CPK', 'troponin', 'bilateral hilar fullness', 'upper zone redistribution', 'normal sinus rhythm', 'peaked T waves', 'diastolic dysfunction', 'basilar artery transient ischemic attack', 'myocardial infarction', 'bradycardic arrest', 'sick sinus syndrome', 'DDD pacer', 'gram-negative rods', 'pleural effusions', 'cardiomegaly', 'aortic regurgitation', 'mitral', 'restrictive lung disease', 'asthen appearance', 'effusions', 'septic shock', 'pneumonia', 'malignant hyperthermia', 'hypotension', 'insulin', 'anemia', 'deep venous thrombosis', 'Full Code']

# %%
original = ['congestive heart failure',
 "Parkinson's",
 'cardiogenic shock',
 'atrial fibrillation',
 'solar urticaria',
 'insufficiency',
 'mitral regurgitation',
 'mib e3 ubiquitin protein ligase 2',
 'Hypercholesterolemia',
 'Peripheral vascular disease',
 'peripheral neuropathy',
 'glaucoma',
 "Parkinson's disease",
 'Osteoarthritis',
 'NPH insulin',
 'epilepsy and/or ataxia with myoclonus as a major feature',
 'diffuse cerebral and cerebellar atrophy-intractable seizures-progressive microcephaly syndrome',
 'infantile cerebral and cerebellar atrophy with postnatal progressive microcephaly',
 'hypomyelination with atrophy of basal ganglia and cerebellum',
 'porencephaly',
 'progressive myoclonic epilepsy type 9',
 'focal epilepsy-intellectual disability-cerebro-cerebellar malformation',
 'neuronal tumor',
 'spastic paraplegia 29',
 'phosphatase 80',
 'albumin',
 'serum',
 'spastic paraplegia 36',
 'Type 2 diabetes mellitus',
 'sick sinus syndrome',
 'cardiomegaly',
 'hypertrophy',
 'restrictive lung disease',
 'multifocal opacities',
 'adenoma',
 'pneumonia',
 'insulin']
